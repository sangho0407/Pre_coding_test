# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# %%
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %%
train.head(3)
# Out:
#    id  digit letter  0  1  2  3  4  5  6  ...  774  775  776  777  778  779  \
# 0   1      5      L  1  1  1  4  3  0  0  ...    2    1    0    1    2    4
# 1   2      0      B  0  4  0  0  4  1  1  ...    0    3    0    1    4    1
# 2   3      4      L  1  1  2  2  1  1  1  ...    3    3    3    0    2    0
#
#    780  781  782  783
# 0    4    4    3    4
# 1    4    2    1    2
# 2    3    0    2    2
#
# [3 rows x 787 columns]

# %%
idx = 1
digit = train.loc[idx, 'digit']
letter = train.loc[idx, 'letter']

img = train.loc[idx, '0':].values.reshape(28, 28).astype(int)

plt.title('index: %i,digit: %s, letter:%s'%(idx,digit,letter))
plt.imshow(img)
plt.show()

# %%
x_train = train.drop(['id', 'digit', 'letter'], axis=1).values
x_train = x_train.reshape(-1, 28, 28, 1)
x_train = x_train/255

# %%
y = train['digit']
y_train = np.zeros((len(y), len(y.unique())))
for i, digit in enumerate(y):
    y_train[i, digit] = 1

# %%
def create_cnn_model(x_train):
    inputs = tf.keras.layers.Input(x_train.shape[1:])

    bn = tf.keras.layers.BatchNormalization()(inputs)
    conv = tf.keras.layers.Conv2D(128, kernel_size=5, strides=1, padding='same', activation='relu')(bn)
    bn = tf.keras.layers.BatchNormalization()(conv)
    conv = tf.keras.layers.Conv2D(128, kernel_size=2, strides=1, padding='same', activation='relu')(bn)
    pool = tf.keras.layers.MaxPooling2D((2, 2))(conv)

    bn = tf.keras.layers.BatchNormalization()(pool)
    conv = tf.keras.layers.Conv2D(256, kernel_size=2, strides=1, padding='same', activation='relu')(bn)
    bn = tf.keras.layers.BatchNormalization()(conv)
    conv = tf.keras.layers.Conv2D(256, kernel_size=2, strides=1, padding='same', activation='relu')(bn)
    pool = tf.keras.layers.MaxPooling2D((2, 2))(conv)

    flatten = tf.keras.layers.Flatten()(pool)

    bn = tf.keras.layers.BatchNormalization()(flatten)
    dense = tf.keras.layers.Dense(1000, activation='relu')(bn)

    bn = tf.keras.layers.BatchNormalization()(dense)
    outputs = tf.keras.layers.Dense(10, activation='softmax')(bn)

    model = tf.keras.models.Model(inputs=inputs, outputs=outputs)

    return model

# %%
model = create_cnn_model(x_train)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 64/64 [==============================] - 2s 14ms/step - loss: 2.6585 - accuracy: 0.4365
# Epoch 2/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.8384 - accuracy: 0.7261
# Epoch 3/50
# 64/64 [==============================] - 1s 13ms/step - loss: 0.5254 - accuracy: 0.8188
# Epoch 4/50
# 64/64 [==============================] - 1s 13ms/step - loss: 0.3095 - accuracy: 0.8955
# Epoch 5/50
# 64/64 [==============================] - 1s 13ms/step - loss: 0.1865 - accuracy: 0.9365
# Epoch 6/50
# 64/64 [==============================] - 1s 13ms/step - loss: 0.1276 - accuracy: 0.9590
# Epoch 7/50
# 64/64 [==============================] - 1s 13ms/step - loss: 0.1234 - accuracy: 0.9653
# Epoch 8/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0754 - accuracy: 0.9766
# Epoch 9/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0445 - accuracy: 0.9902
# Epoch 10/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0548 - accuracy: 0.9834
# Epoch 11/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0437 - accuracy: 0.9873
# Epoch 12/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0638 - accuracy: 0.9775
# Epoch 13/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0796 - accuracy: 0.9727
# Epoch 14/50
# 64/64 [==============================] - 1s 13ms/step - loss: 0.0895 - accuracy: 0.9683
# Epoch 15/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0978 - accuracy: 0.9639
# Epoch 16/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0622 - accuracy: 0.9800
# Epoch 17/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0798 - accuracy: 0.9746
# Epoch 18/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0619 - accuracy: 0.9819
# Epoch 19/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0426 - accuracy: 0.9878
# Epoch 20/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0319 - accuracy: 0.9912
# Epoch 21/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0288 - accuracy: 0.9907
# Epoch 22/50
# 64/64 [==============================] - 1s 15ms/step - loss: 0.0217 - accuracy: 0.9946
# Epoch 23/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0077 - accuracy: 0.9990
# Epoch 24/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0093 - accuracy: 0.9976
# Epoch 25/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0042 - accuracy: 0.9995
# Epoch 26/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 27/50
# 64/64 [==============================] - 1s 15ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 28/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0022 - accuracy: 0.9995
# Epoch 29/50
# 64/64 [==============================] - 1s 14ms/step - loss: 9.9524e-04 - accuracy: 1.0000
# Epoch 30/50
# 64/64 [==============================] - 1s 13ms/step - loss: 7.2713e-04 - accuracy: 1.0000
# Epoch 31/50
# 64/64 [==============================] - 1s 13ms/step - loss: 8.0020e-04 - accuracy: 1.0000
# Epoch 32/50
# 64/64 [==============================] - 1s 13ms/step - loss: 6.2437e-04 - accuracy: 1.0000
# Epoch 33/50
# 64/64 [==============================] - 1s 14ms/step - loss: 5.6614e-04 - accuracy: 1.0000
# Epoch 34/50
# 64/64 [==============================] - 1s 14ms/step - loss: 3.8361e-04 - accuracy: 1.0000
# Epoch 35/50
# 64/64 [==============================] - 1s 14ms/step - loss: 5.5243e-04 - accuracy: 1.0000
# Epoch 36/50
# 64/64 [==============================] - 1s 14ms/step - loss: 5.9915e-04 - accuracy: 1.0000
# Epoch 37/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 38/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 39/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0045 - accuracy: 0.9985
# Epoch 40/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0628 - accuracy: 0.9805
# Epoch 41/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.6187 - accuracy: 0.8345
# Epoch 42/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.4359 - accuracy: 0.8647
# Epoch 43/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.1654 - accuracy: 0.9448
# Epoch 44/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0521 - accuracy: 0.9829
# Epoch 45/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0250 - accuracy: 0.9941
# Epoch 46/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0177 - accuracy: 0.9951
# Epoch 47/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0147 - accuracy: 0.9961
# Epoch 48/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0107 - accuracy: 0.9976
# Epoch 49/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0084 - accuracy: 0.9985
# Epoch 50/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0048 - accuracy: 0.9995

# %%
x_test = test.drop(['id', 'letter'], axis=1).values
x_test = x_test.reshape(-1, 28, 28, 1)
x_test = x_test/255

submission = pd.read_csv('./submission.csv')
submission['digit'] = np.argmax(model.predict(x_test), axis=1)
submission.head()
# Out:
# 640/640 [==============================] - 3s 5ms/step
#      id  digit
# 0  2049      6
# 1  2050      9
# 2  2051      6
# 3  2052      0
# 4  2053      3

# %%
plt.title('index: %i,digit: %s, letter:%s'%(2049,digit,letter))
plt.imshow(img)
plt.show()
